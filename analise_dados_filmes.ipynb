# %% [markdown]
# ### Base de Dados importada ➡ https://www.kaggle.com/datasets/utkarshx27/movies-dataset
# ### Problema ➡ Limpar Base de Dados e Trazer informações necessárias
# ### Solução abaixo 👇🏼

# %%
import pandas as pd

table_filmes = pd.read_csv("movie_dataset.csv")
display(table_filmes)
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### Tratando e Analisando Valores Nulos

# %%
table_filmes['genres'] = table_filmes['genres'].fillna('without genres')

table_filmes['homepage'] = table_filmes['homepage'].fillna('no home page')

table_filmes['keywords'] = table_filmes['keywords'].fillna('no keywords')

table_filmes['tagline'] = table_filmes['tagline'].fillna('no tagline')

display(table_filmes)
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                            without genres
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### Tratando e Analisando a quantidade de filmes por genêros

# %%
qnt_filmes_genero = table_filmes['genres'].value_counts()
display(qnt_filmes_genero)
# Out:
# Drama                                                370
# Comedy                                               282
# Drama Romance                                        164
# Comedy Romance                                       144
# Comedy Drama                                         142
#                                                     ...
# Action Comedy Family Adventure                         1
# Drama Adventure Western                                1
# Adventure Fantasy Action Romance                       1
# Fantasy Action Adventure Science Fiction Thriller      1
# Comedy Drama Romance TV Movie                          1
# Name: genres, Length: 1169, dtype: int64

# %% [markdown]
# ### Tratando e Analisando o orçamento por categoria

# %%
orcamento_genero = table_filmes[['budget', 'genres']].groupby(['genres']).sum()
display(orcamento_genero)
# Out:
#                                                       budget
# genres
# Action                                             834000000
# Action Adventure                                   819200000
# Action Adventure Animation Comedy Family           246000000
# Action Adventure Animation Comedy Science Fiction          0
# Action Adventure Animation Family                   92000000
# ...                                                      ...
# Western Drama                                       27000000
# Western Drama Adventure Thriller                   135000000
# Western History                                     10000000
# Western History War                                145000000
# without genres                                       3700001
#
# [1169 rows x 1 columns]

# %% [markdown]
# ### Análisando e Tratando A soma dos Votos e Média por Genêro/Filme

# %%
votos_total_media = table_filmes[['genres', 'title', 'vote_average', 'vote_count']].groupby(['genres', 'title']).sum()
display(votos_total_media)
# Out:
#                                                                 vote_average  \
# genres         title
# Action         Agent Cody Banks                                          5.0
#                Alatriste                                                 5.6
#                American Heist                                            4.3
#                Bloodsport                                                6.6
#                Criminal                                                  5.7
# ...                                                                      ...
# without genres The Book of Mormon Movie, Volume 1: The Journey           5.0
#                The Little Ponderosa Zoo                                  2.0
#                The Looking Glass                                         7.0
#                The Outrageous Sophie Tucker                              0.0
#                UnDivided                                                 0.0
#
# ...

# %% [markdown]
# ### Analisando e Tratando Filmes com a Nota > 5

# %%
filmes_nota_maior_5 = table_filmes.loc[table_filmes['vote_average'] > 5.0, ['genres', 'title', 'vote_average']]
display(filmes_nota_maior_5)
# Out:
#                                         genres  \
# 0     Action Adventure Fantasy Science Fiction
# 1                     Adventure Fantasy Action
# 2                       Action Adventure Crime
# 3                  Action Crime Drama Thriller
# 4             Action Adventure Science Fiction
# ...                                        ...
# 4798                     Action Crime Thriller
# 4799                            Comedy Romance
# 4800             Comedy Drama Romance TV Movie
# 4801                            without genres
# 4802                               Documentary
#
#                                          title  vote_average
# 0                                       Avatar           7.2
# 1     Pirates of the Caribbean: At World's End           6.9
# 2                                      Spectre           6.3
# 3                        The Dark Knight Rises           7.6
# 4                                  John Carter           6.1
# ...

# %% [markdown]
# ### Analisando e Filmes com a Nota < 5

# %%
filmes_nota_menor_5 = table_filmes.loc[table_filmes['vote_average'] < 5.0, ['genres', 'title', 'vote_average']]
display(filmes_nota_menor_5)
# Out:
#                                         genres                         title  \
# 83    Action Adventure Science Fiction Romance                    The Lovers
# 91            Action Adventure Science Fiction  Independence Day: Resurgence
# 138            Action Adventure Family Fantasy            The Last Airbender
# 162                                     Action                       Stealth
# 210                       Action Crime Fantasy                Batman & Robin
# ...                                        ...                           ...
# 4783                           Thriller Horror                      Backmask
# 4785                                     Drama          Stories of Our Lives
# 4787                  Science Fiction Thriller      All Superheroes Must Die
# 4791                                    Horror                   Tin Can Man
# 4794                    Thriller Horror Comedy  Sanctuary: Quite a Conundrum
#
#       vote_average
# 83             4.8
# ...

# %%
maior_5 = 4189
menor_5 = 528
percentutal = (menor_5 / maior_5) * 100

print(percentutal)
# Out:
# 12.604440200525186

# %% [markdown]
# ### Resultado da Análise de Dados
# - O genêro com mais lançamento de filmes é o *Genêro Drama*
# - A categoria com orçamento mais alto é a *Categoria Action*
# - A diference na votação da média dos votos dos filmes com >5 ou com <5 é equivalente à 12% sob o total dos filmes
